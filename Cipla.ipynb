# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
train_df= pd.read_csv('train.csv')
test_df= pd.read_csv('test.csv')

# %%
train_df
# Out:
#       Customer ID               Name Gender  Age  Income (USD)  \
# 0         C-36995   Frederica Shealy      F   56       1933.05
# 1         C-33999  America Calderone      M   32       4952.91
# 2          C-3770      Rosetta Verne      F   65        988.19
# 3         C-26480         Zoe Chitty      F   65           NaN
# 4         C-23459       Afton Venema      F   31       2614.77
# ...           ...                ...    ...  ...           ...
# 29995     C-43723  Angelyn Clevenger      M   38       4969.41
# 29996     C-32511       Silas Slaugh      M   20       1606.88
# 29997      C-5192       Carmelo Lone      F   49           NaN
# 29998     C-12172      Carolann Osby      M   38       2417.71
# 29999     C-33003  Bridget Garibaldi      F   63       3068.24
#
#       Income Stability            Profession     Type of Employment  \
# 0                  Low               Working            Sales staff
# 1                  Low               Working                    NaN
# ...

# %%
test_df
# Out:
#       Customer ID              Name Gender  Age  Income (USD)  \
# 0         C-26247  Tandra Olszewski      F   47       3472.69
# 1         C-35067     Jeannette Cha      F   57       1184.84
# 2         C-34590      Keva Godfrey      F   52       1266.27
# 3         C-16668      Elva Sackett      M   65       1369.72
# 4         C-12196    Sade Constable      F   60       1939.23
# ...           ...               ...    ...  ...           ...
# 19995      C-9076    Tobias Davilla      F   19       1349.60
# 19996     C-17587    Evelina Hodges      M   22       2019.78
# 19997     C-46479   Karlyn Mckinzie      M   19       2252.03
# 19998      C-3099    Mariana Pulver      F   21       1845.35
# 19999     C-43482   Mechelle Boddie      M   21       5233.16
#
#       Income Stability            Profession Type of Employment    Location  \
# 0                  Low  Commercial associate           Managers  Semi-Urban
# ...

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 24 columns):
# Customer ID                    30000 non-null object
# Name                           30000 non-null object
# Gender                         29947 non-null object
# Age                            30000 non-null int64
# Income (USD)                   25424 non-null float64
# Income Stability               28317 non-null object
# Profession                     30000 non-null object
# Type of Employment             22730 non-null object
# Location                       30000 non-null object
# Loan Amount Request (USD)      30000 non-null float64
# Current Loan Expenses (USD)    29828 non-null float64
# Expense Type 1                 30000 non-null object
# Expense Type 2                 30000 non-null object
# Dependents                     27507 non-null float64
# Credit Score                   28297 non-null float64
# No. of Defaults                30000 non-null int64
# ...

# %%
train_df.describe()
# Out:
#                 Age  Income (USD)  Loan Amount Request (USD)  \
# count  30000.000000  2.542400e+04               30000.000000
# mean      40.092300  2.630574e+03               88826.333855
# std       16.045129  1.126272e+04               59536.949605
# min       18.000000  3.777000e+02                6048.240000
# 25%       25.000000  1.650457e+03               41177.755000
# 50%       40.000000  2.222435e+03               75128.075000
# 75%       55.000000  3.090593e+03              119964.605000
# max       65.000000  1.777460e+06              621497.820000
#
#        Current Loan Expenses (USD)    Dependents  Credit Score  \
# count                 29828.000000  27507.000000  28297.000000
# mean                    400.936876      2.253027    739.885381
# std                     242.545375      0.951162     72.163846
# min                    -999.000000      1.000000    580.000000
# 25%                     247.667500      2.000000    681.880000
# ...

# %%
train_df.isnull().sum()
# Out:
# Customer ID                       0
# Name                              0
# Gender                           53
# Age                               0
# Income (USD)                   4576
# Income Stability               1683
# Profession                        0
# Type of Employment             7270
# Location                          0
# Loan Amount Request (USD)         0
# Current Loan Expenses (USD)     172
# Expense Type 1                    0
# Expense Type 2                    0
# Dependents                     2493
# Credit Score                   1703
# No. of Defaults                   0
# Has Active Credit Card         1566
# Property ID                       0
# Property Age                   4850
# Property Type                     0
# Property Location               356
# Co-Applicant                      0
# Property Price                    0
# Loan Sanction Amount (USD)      340
# dtype: int64

# %%
train_df.nunique()
# Out:
# Customer ID                    30000
# Name                           30000
# Gender                             2
# Age                               48
# Income (USD)                   24429
# Income Stability                   2
# Profession                         8
# Type of Employment                18
# Location                           3
# Loan Amount Request (USD)      29982
# Current Loan Expenses (USD)    24041
# Expense Type 1                     2
# Expense Type 2                     2
# Dependents                        10
# Credit Score                   17586
# No. of Defaults                    2
# Has Active Credit Card             3
# Property ID                      999
# Property Age                   24179
# Property Type                      4
# Property Location                  3
# Co-Applicant                       3
# Property Price                 29632
# Loan Sanction Amount (USD)     21450
# dtype: int64

# %%
plt.figure(figsize=(10,10))
sns.heatmap(train_df.corr(), annot=True, linewidths=0.5, fmt= '.3f')

# %%
train_df.shape,test_df.shape
# Out:
# ((30000, 24), (20000, 23))

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 24 columns):
# Customer ID                    30000 non-null object
# Name                           30000 non-null object
# Gender                         29947 non-null object
# Age                            30000 non-null int64
# Income (USD)                   25424 non-null float64
# Income Stability               28317 non-null object
# Profession                     30000 non-null object
# Type of Employment             22730 non-null object
# Location                       30000 non-null object
# Loan Amount Request (USD)      30000 non-null float64
# Current Loan Expenses (USD)    29828 non-null float64
# Expense Type 1                 30000 non-null object
# Expense Type 2                 30000 non-null object
# Dependents                     27507 non-null float64
# Credit Score                   28297 non-null float64
# No. of Defaults                30000 non-null int64
# ...

# %%
train_df.drop(columns='Name',inplace=True)

# %%
test_df.drop(columns='Name',inplace=True)

# %%
train_df.columns
# Out:
# Index(['Customer ID', 'Gender', 'Age', 'Income (USD)', 'Income Stability',
#        'Profession', 'Type of Employment', 'Location',
#        'Loan Amount Request (USD)', 'Current Loan Expenses (USD)',
#        'Expense Type 1', 'Expense Type 2', 'Dependents', 'Credit Score',
#        'No. of Defaults', 'Has Active Credit Card', 'Property ID',
#        'Property Age', 'Property Type', 'Property Location', 'Co-Applicant',
#        'Property Price', 'Loan Sanction Amount (USD)'],
#       dtype='object')

# %%
cat_cols=train_df.select_dtypes(['object']).columns 
cat_cols
# Out:
# Index(['Customer ID', 'Gender', 'Income Stability', 'Profession',
#        'Type of Employment', 'Location', 'Expense Type 1', 'Expense Type 2',
#        'Has Active Credit Card', 'Property Location'],
#       dtype='object')

# %%
cat_cols=['Gender', 'Income Stability', 'Profession',
       'Type of Employment', 'Location', 'Expense Type 1', 'Expense Type 2',
       'Has Active Credit Card', 'Property Location']

# %%
train_df.isnull().sum()
# Out:
# Customer ID                       0
# Gender                           53
# Age                               0
# Income (USD)                   4576
# Income Stability               1683
# Profession                        0
# Type of Employment             7270
# Location                          0
# Loan Amount Request (USD)         0
# Current Loan Expenses (USD)     172
# Expense Type 1                    0
# Expense Type 2                    0
# Dependents                     2493
# Credit Score                   1703
# No. of Defaults                   0
# Has Active Credit Card         1566
# Property ID                       0
# Property Age                   4850
# Property Type                     0
# Property Location               356
# Co-Applicant                      0
# Property Price                    0
# Loan Sanction Amount (USD)      340
# dtype: int64

# %%
test_df.isnull().sum()
# Out:
# Customer ID                       0
# Gender                           31
# Age                               0
# Income (USD)                    750
# Income Stability                813
# Profession                        0
# Type of Employment             4689
# Location                          0
# Loan Amount Request (USD)         0
# Current Loan Expenses (USD)      83
# Expense Type 1                    0
# Expense Type 2                    0
# Dependents                     1142
# Credit Score                    743
# No. of Defaults                   0
# Has Active Credit Card         1076
# Property ID                       0
# Property Age                    892
# Property Type                     0
# Property Location               160
# Co-Applicant                      0
# Property Price                    0
# dtype: int64

# %%
train_df['Gender'].value_counts()
# Out:
# M    15053
# F    14894
# Name: Gender, dtype: int64

# %%
for col in train_df.select_dtypes('object').columns:
    print(col, train_df[col].nunique())
# Out:
# Customer ID 30000
# Gender 2
# Income Stability 2
# Profession 8
# Type of Employment 18
# Location 3
# Expense Type 1 2
# Expense Type 2 2
# Has Active Credit Card 3
# Property Location 3

# %%
train_df['Gender']=train_df['Gender'].fillna(train_df['Gender'].mode()[0])

# %%
test_df['Gender']=test_df['Gender'].fillna(test_df['Gender'].mode()[0])

# %%
train_df['Income Stability'].value_counts()
# Out:
# Low     25751
# High     2566
# Name: Income Stability, dtype: int64

# %%
train_df['Income Stability']=train_df['Income Stability'].fillna(train_df['Income Stability'].mode()[0])

# %%
test_df['Income Stability']=test_df['Income Stability'].fillna(test_df['Income Stability'].mode()[0])

# %%
train_df['Profession'].value_counts()
# Out:
# Working                 16926
# Commercial associate     7962
# Pensioner                2740
# State servant            2366
# Unemployed                  2
# Businessman                 2
# Student                     1
# Maternity leave             1
# Name: Profession, dtype: int64

# %%
train_df['Type of Employment'].value_counts()
# Out:
# Laborers                 5578
# Sales staff              3736
# Core staff               3230
# Managers                 2495
# Drivers                  1606
# Accountants              1379
# High skill tech staff    1307
# Medicine staff            864
# Security staff            579
# Cooking staff             566
# Private service staff     342
# Cleaning staff            341
# Low-skill Laborers        162
# Secretaries               161
# Waiters/barmen staff      149
# Realty agents              86
# IT staff                   77
# HR staff                   72
# Name: Type of Employment, dtype: int64

# %%
train_df['Has Active Credit Card'].value_counts()
# Out:
# Active         9771
# Inactive       9466
# Unpossessed    9197
# Name: Has Active Credit Card, dtype: int64

# %%
train_df['Property Location'].value_counts()
# Out:
# Semi-Urban    10387
# Rural         10041
# Urban          9216
# Name: Property Location, dtype: int64

# %%
train_df.isnull().sum()
# Out:
# Customer ID                       0
# Gender                            0
# Age                               0
# Income (USD)                      0
# Income Stability                  0
# Profession                        0
# Type of Employment             7270
# Location                          0
# Loan Amount Request (USD)         0
# Current Loan Expenses (USD)       0
# Expense Type 1                    0
# Expense Type 2                    0
# Dependents                        0
# Credit Score                      0
# No. of Defaults                   0
# Has Active Credit Card         1566
# Property ID                       0
# Property Age                      0
# Property Type                     0
# Property Location               356
# Co-Applicant                      0
# Property Price                    0
# Loan Sanction Amount (USD)      340
# dtype: int64

# %%
train_df.describe()
# Out:
#                 Age  Income (USD)  Loan Amount Request (USD)  \
# count  30000.000000  2.542400e+04               30000.000000
# mean      40.092300  2.630574e+03               88826.333855
# std       16.045129  1.126272e+04               59536.949605
# min       18.000000  3.777000e+02                6048.240000
# 25%       25.000000  1.650457e+03               41177.755000
# 50%       40.000000  2.222435e+03               75128.075000
# 75%       55.000000  3.090593e+03              119964.605000
# max       65.000000  1.777460e+06              621497.820000
#
#        Current Loan Expenses (USD)    Dependents  Credit Score  \
# count                 29828.000000  27507.000000  28297.000000
# mean                    400.936876      2.253027    739.885381
# std                     242.545375      0.951162     72.163846
# min                    -999.000000      1.000000    580.000000
# 25%                     247.667500      2.000000    681.880000
# ...

# %%
train_df['Dependents']=train_df['Dependents'].fillna(train_df['Dependents'].median())

# %%
test_df['Dependents']=test_df['Dependents'].fillna(test_df['Dependents'].median())

# %%
train_df["Current Loan Expenses (USD)"]=train_df["Current Loan Expenses (USD)"].fillna(train_df['Current Loan Expenses (USD)'].median())

# %%
test_df["Current Loan Expenses (USD)"]=test_df["Current Loan Expenses (USD)"].fillna(test_df['Current Loan Expenses (USD)'].median())

# %%
train_df["Current Loan Expenses (USD)"].mode()
# Out:
# 0   -999.0
# dtype: float64

# %%
train_df["Credit Score"]=train_df["Credit Score"].fillna(train_df['Credit Score'].median())

# %%
test_df["Credit Score"]=test_df["Credit Score"].fillna(test_df['Credit Score'].median())

# %%
train_df["Property Age"]=train_df["Property Age"].fillna(train_df['Property Age'].median())

# %%
test_df["Property Age"]=test_df["Property Age"].fillna(test_df['Property Age'].median())

# %%
train_df["Income (USD)"]=train_df["Income (USD)"].fillna(train_df['Income (USD)'].mean())

# %%
test_df["Income (USD)"]=test_df["Income (USD)"].fillna(test_df['Income (USD)'].mean())

# %%
train_df = pd.get_dummies(train_df, columns=['Gender', 'Income Stability', 'Profession',
       'Type of Employment', 'Location', 'Expense Type 1', 'Expense Type 2',
       'Has Active Credit Card', 'Property Location'])

# %%
test_df = pd.get_dummies(test_df, columns=['Gender', 'Income Stability', 'Profession',
       'Type of Employment', 'Location', 'Expense Type 1', 'Expense Type 2',
       'Has Active Credit Card', 'Property Location'])

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 56 columns):
# Age                                         30000 non-null int64
# Income (USD)                                30000 non-null float64
# Loan Amount Request (USD)                   30000 non-null float64
# Current Loan Expenses (USD)                 30000 non-null float64
# Dependents                                  30000 non-null float64
# Credit Score                                30000 non-null float64
# No. of Defaults                             30000 non-null int64
# Property ID                                 30000 non-null int64
# Property Age                                30000 non-null float64
# Property Type                               30000 non-null int64
# Co-Applicant                                30000 non-null int64
# Property Price                              30000 non-null float64
# ...

# %%
train_df.drop(columns='Customer ID',inplace=True)

# %%
test_df.drop(columns='Customer ID',inplace=True)

# %%
from sklearn.model_selection import train_test_split

# %%
train_df.dropna(inplace=True)

# %%
test_df.dropna(inplace=True)

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19257 entries, 0 to 19999
# Data columns (total 54 columns):
# Age                                         19257 non-null int64
# Income (USD)                                19257 non-null float64
# Loan Amount Request (USD)                   19257 non-null float64
# Current Loan Expenses (USD)                 19257 non-null float64
# Dependents                                  19257 non-null float64
# Credit Score                                19257 non-null float64
# No. of Defaults                             19257 non-null int64
# Property ID                                 19257 non-null int64
# Property Age                                19257 non-null float64
# Property Type                               19257 non-null int64
# Co-Applicant                                19257 non-null object
# Property Price                              19257 non-null object
# Gender_F                                    19257 non-null uint8
# ...

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29660 entries, 0 to 29999
# Data columns (total 56 columns):
# Age                                         29660 non-null int64
# Income (USD)                                29660 non-null float64
# Loan Amount Request (USD)                   29660 non-null float64
# Current Loan Expenses (USD)                 29660 non-null float64
# Dependents                                  29660 non-null float64
# Credit Score                                29660 non-null float64
# No. of Defaults                             29660 non-null int64
# Property ID                                 29660 non-null int64
# Property Age                                29660 non-null float64
# Property Type                               29660 non-null int64
# Co-Applicant                                29660 non-null int64
# Property Price                              29660 non-null float64
# ...

# %%
X_train = train_df.drop("Loan Sanction Amount (USD)", axis=1)
Y_train = train_df["Loan Sanction Amount (USD)"]

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
GBoost = GradientBoostingRegressor(n_estimators=5000, learning_rate=0.05, max_depth=4, max_features='sqrt',
                                   min_samples_leaf=15, min_samples_split=10, loss='huber', random_state=0)
GBoost.fit(X_train, Y_train)
# Out:
# GradientBoostingRegressor(alpha=0.9, ccp_alpha=0.0, criterion='friedman_mse',
#                           init=None, learning_rate=0.05, loss='huber',
#                           max_depth=4, max_features='sqrt', max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=15, min_samples_split=10,
#                           min_weight_fraction_leaf=0.0, n_estimators=5000,
#                           n_iter_no_change=None, presort='deprecated',
#                           random_state=0, subsample=1.0, tol=0.0001,
#                           validation_fraction=0.1, verbose=0, warm_start=False)

# %%
ypred=GBoost.predict(test_df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-96-dd7d867cd4bd> in <module>
# ----> 1 ypred=GBoost.predict(test_df)
#
# ~\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py in predict(self, X)
#    2565             The predicted values.
#    2566         """
# -> 2567         X = check_array(X, dtype=DTYPE, order="C", accept_sparse='csr')
#    2568         # In regression we can directly return the raw value from the trees.
#    2569         return self._raw_predict(X).ravel()
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     529                     array = array.astype(dtype, casting="unsafe", copy=False)
#     530                 else:
# ...

# %%
msno.matrix
